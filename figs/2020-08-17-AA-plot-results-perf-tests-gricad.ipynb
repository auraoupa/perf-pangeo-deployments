# %% [markdown]
# # Résults

# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib 

matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
matplotlib.rcParams.update({'font.size': 20})

# %%
workers=[2,8,24,32,64,128]
timing=[np.mean([59,71,65]),np.mean([20,21,27]),13,10,np.mean([9.7,10.08]),9.95]
timing_error=[np.std([59,71,65]),np.std([20,21,27]),0,0,np.std([9.7,10.08]),0]
timing_scalable=[np.mean([59,71,65]),np.mean([59,71,65])/4,np.mean([59,71,65])/12,np.mean([59,71,65])/16,np.mean([59,71,65])/32,np.mean([59,71,65])/128]

# %%
marker_style = dict(linestyle=':', color='cornflowerblue', markersize=10)

fig, ax = plt.subplots()
fig.figsize=(20, 8)
plt.errorbar(workers,timing,yerr=timing_error,fmt='o-',color='cornflowerblue',label='results')
plt.plot(workers,timing_scalable,'.-',marker='X',color='black',label='scalable')


plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel('Number of workers')
plt.ylabel('Walltime in minutes')
plt.title('Performance tests of DAHU - 201.19GB memory')
plt.savefig('figs/Perf-gricad.png', bbox_inches='tight')
